# %%
import pandas as pd
import seaborn as sns

# %%
network = pd.read_csv('0831_128_500.csv')

# %%
network.head()
# Out:
#                                                   Id  \
# 0  Energy efficient and low-cost server architect...
# 1  Three-dimensional core–shell structured NiCo2O...
# 2  Simple P-I diagram for structural components b...
# 3  Study on the optimization of gauge expansion f...
# 4  Compact Ultra Wide-Band and Tri-Band Antenna f...
#
#                                                Label  timeset  Degree  \
# 0  Energy efficient and low-cost server architect...      NaN     311
# 1  Three-dimensional core–shell structured NiCo2O...      NaN     618
# 2  Simple P-I diagram for structural components b...      NaN     746
# 3  Study on the optimization of gauge expansion f...      NaN     569
# 4  Compact Ultra Wide-Band and Tri-Band Antenna f...      NaN     721
#
#    Weighted Degree  Eccentricity  closnesscentrality  \
# 0       231.233519             5            0.538141
# 1       479.173403             4            0.659490
# 2       596.450950             4            0.717190
# ...

# %%
sns.distplot(network['Degree'])
# Out:
# C:\Users\rubby\Anaconda3\envs\python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Degree', ylabel='Density'>

# %%
degreeL = network.loc[network['Degree'] < 100]
degreeM = network.loc[(network['Degree'] >= 100) & (network['Degree'] < 500)]
degreeH = network.loc[network['Degree'] >= 500]

# %%
dL_s = degreeL.sample(n=3, random_state=7)
dM_s = degreeM.sample(n=3, random_state=7)
dH_s = degreeH.sample(n=3, random_state=7)

# %%
dL_s
# Out:
#                                                     Id  \
# 980  Optimization of vehicle speed in urban road us...
# 787  Analysis of improvement effect of rail design ...
# 954  Effect of Cu, Cr, S doped Tio2 for transparent...
#
#                                                  Label  timeset  Degree  \
# 980  Optimization of vehicle speed in urban road us...      NaN      45
# 787  Analysis of improvement effect of rail design ...      NaN       1
# 954  Effect of Cu, Cr, S doped Tio2 for transparent...      NaN       1
#
#      Weighted Degree  Eccentricity  closnesscentrality  \
# 980        32.679314             5            0.454865
# 787         0.700356             1            1.000000
# 954         0.706820             6            0.285855
#
#      harmonicclosnesscentrality  betweenesscentrality  modularity_class
# 980                    0.481544              0.000411                 1
# 787                    1.000000              0.000000                 8
# ...

# %%
dM_s
# Out:
#                                                     Id  \
# 441  Cation-Regulated Transformation for Continuous...
# 401  Membraneless biofuel cells using new cathodic ...
# 751  Experimental and Modeling Study of Vapor Liqui...
#
#                                                  Label  timeset  Degree  \
# 441  Cation-Regulated Transformation for Continuous...      NaN     240
# 401  Membraneless biofuel cells using new cathodic ...      NaN     413
# 751  Experimental and Modeling Study of Vapor Liqui...      NaN     256
#
#      Weighted Degree  Eccentricity  closnesscentrality  \
# 441       177.157456             5            0.511648
# 401       311.203700             4            0.571709
# 751       190.044754             4            0.516415
#
#      harmonicclosnesscentrality  betweenesscentrality  modularity_class
# 441                    0.577090              0.000457                 1
# 401                    0.660510              0.000180                 3
# ...

# %%
dH_s
# Out:
#                                                     Id  \
# 156  Design and analysis of an effective graphics c...
# 77   Comparison of electrical and interfacial chara...
# 425  High-resolution climate projections for a dens...
#
#                                                  Label  timeset  Degree  \
# 156  Design and analysis of an effective graphics c...      NaN     559
# 77   Comparison of electrical and interfacial chara...      NaN     800
# 425  High-resolution climate projections for a dens...      NaN     553
#
#      Weighted Degree  Eccentricity  closnesscentrality  \
# 156       430.955909             4            0.632609
# 77        650.423630             4            0.742821
# 425       423.792792             4            0.627155
#
#      harmonicclosnesscentrality  betweenesscentrality  modularity_class
# 156                    0.730241              0.002243                 3
# 77                     0.838345              0.003755                 1
# ...

# %%
raw_data = pd.read_csv('data/2019-2020.csv')

# %%
raw_data.head()
# Out:
#                                              Authors  \
# 0             Choi D.Y., Oh J.H., Kim J.K., Lee S.E.
# 1                           Ji J., Chung Y., Kwon Y.
# 2        Nguyen X.T., Nguyen T.N., Lee H.-J., Kim H.
# 3                                Nov L., Chung J.-Y.
# 4  Karunakaran G., Cho E.-B., Kumar G.S., Kolesni...
#
#                                         Author(s) ID  \
# 0   57221531822;57193057094;57193067620;55857982000;
# 1                57195592309;56984923500;7403457084;
# 2    57197875076;57210219943;8161276300;34770344200;
# 3                           57222570971;56681595800;
# 4  55480032500;7202649980;55430366400;57057275500...
#
#                                                Title  Year  \
# 0  Energy efficient and low-cost server architect...  2020
# 1  The effects of cobalt phthalocyanine and polya...  2020
# 2  An accurate weight binarization scheme for CNN...  2020
# 3  Dielectric property characterisation of thin f...  2020
# ...

# %%
def get_abstract(df) :
    abstract = []
    for la in df['Label'] :
        df_s = raw_data.loc[raw_data['Title'] == la]        
        abstract.append((df_s['Title'].values[0]) + ' ' + (df_s['Abstract'].values[0]))
    return abstract

# %%
get_abstract(dL_s)
# Out:
# ['Optimization of vehicle speed in urban road using dynamic programming Recently, air pollution and global warming are considered as major social issues. Transportation is one of the contributors to air pollutant emissions by consuming fossil fuel. Energy-efficient driving, which reduces energy consumption by improving driving control, is needed to reduce emissions. In this paper, optimal speed profile for energy-efficient driving is generated by using dynamic programming that can achieve a global optimal solution. A conventional vehicle is selected as a target vehicle and modeled based on longitudinal dynamics. The vehicle travels in the urban road, taking into account different road conditions and constraints(e.g., traffic signal and speed limit). It is assumed that the vehicle has access to the traffic signal system data and geographical information by vehicle-to-information(V2I). The selected roads are discretized for optimization, and the road characteristics and traffic signals
# ...

# %%
get_abstract(dM_s)
# Out:
# ['Cation-Regulated Transformation for Continuous Two-Dimensional Tin Monosulfide The synthesis of a continuous and high-quality large-area layer is a key research area in the field of two-dimensional (2D) metal chalcogenides. To date, several techniques, including chemical vapor deposition and sulfurization/selenization, have been proposed for the synthesis of 2D metal chalcogenides. These techniques are based on the substitutional reaction of anions, that is, replacement of oxygen with chalcogen elements. This study uses a new approach based on cation-regulated transformation. An SnS2 layer, a parent material, is grown by atomic layer deposition, followed by reaction with bis(1-dimethlamino-2-methyl-2-propoxy)tin(II) at a temperature of 270 °C to form SnS. The reaction occurs predominantly along grain boundaries. The transformation self-terminates once the pregrown SnS2 is completely consumed. The devices utilizing the transformed layers, such as gas sensors and thin-film transistor
# ...

# %%
get_abstract(dH_s)
# Out:
# ['Design and analysis of an effective graphics collaborative editing system With the rapid development of computer-supported cooperative work (CSCW) technology, graphical collaborative editing plays an increasingly important role in CSCW. The most important technique in graphics co-editing is the consistency of graphics co-editing, which mainly includes causality consistency, consistency of results, and consistency of intention. Most of the previous research was abstract and ineffective, lacking theoretical depth and scalability. However, because the algorithm proposed in this paper can solve the contradictions in the consistency of graphical collaborative editing, the research in this paper has particularity, and the results will be proven by the experiment described in the paper. In order to solve the consistency conflict problem of graphic collaborative editing, the common graphics collaborative editing algorithm (CGCE algorithm) is proposed. It is proposed not only to perfect and
# ...

# %%
import nltk
from nltk.corpus import stopwords

dH_keywords = []

def get_keywords(data) :
    clean_data = []
    tokens = []
    for doc in data :
        tokens.append(nltk.regexp_tokenize(doc.lower(), '[A-Za-z]+'))
    for words in tokens :
        clean_words = []
        for word in words :
            if len(word) > 3:
                if word not in stopwords.words('english'):
                    clean_data.append(word)
    return clean_data

# %%
dL_keywords = get_keywords(get_abstract(dL_s))
dM_keywords = get_keywords(get_abstract(dM_s))
dH_keywords = get_keywords(get_abstract(dH_s))

# %%
import random

dL_keywords_s = random.sample(dL_keywords, 10)
dL_keywords_s
# Out:
# ['restrict',
#  'investments',
#  'time',
#  'visible',
#  'arrangement',
#  'reduces',
#  'railroad',
#  'travels',
#  'constraints',
#  'absorption']

# %%
dM_keywords_s = random.sample(dM_keywords, 10)
dM_keywords_s
# Out:
# ['activity',
#  'like',
#  'fuels',
#  'glucose',
#  'korean',
#  'dimensional',
#  'bonded',
#  'atomic',
#  'liquid',
#  'quality']

# %%
dH_keywords_s = random.sample(dH_keywords, 10)
dH_keywords_s
# Out:
# ['future',
#  'sample',
#  'editing',
#  'algorithm',
#  'process',
#  'increase',
#  'cooperative',
#  'characteristics',
#  'collaborative',
#  'historical']
