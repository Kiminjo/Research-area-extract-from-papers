# %%
import pandas as pd
import pickle5 as pickle
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
filepath = 'data/similarity_matrix.pickle'

# %%
with open(filepath, 'rb') as lf :
        similarity_vector = pickle.load(lf)

# %%
kmeans = KMeans(n_clusters= 40, random_state=1004).fit(similarity_vector)
clusters = kmeans.labels_

clusters = pd.DataFrame(clusters)
a = clusters[0].value_counts()

ax = a.plot(kind='bar', title='Number of cluster', figsize=(12, 4), legend=None)
ax.set_xlabel('Cluster', fontsize=12)
ax.set_ylabel('Number of documents', fontsize=12)
# Out:
# Text(0, 0.5, 'Number of documents')

# %%
clusters
# Out:
#       cluster
# 0          27
# 1           4
# 2          38
# 3          38
# 4          19
# ...       ...
# 4041       38
# 4042       38
# 4043        5
# 4044       38
# 4045       38
#
# [4046 rows x 1 columns]

# %%
clusters.columns = ['cluster']

# %%
a = clusters['cluster'].value_counts()

# %%
a
# Out:
# 4     242
# 33    169
# 3     158
# 22    157
# 8     148
# 32    137
# 15    134
# 34    128
# 35    120
# 17    118
# 39    116
# 18    114
# 7     113
# 14    112
# 21    110
# 12    109
# 30    108
# 23    104
# 9      97
# 28     97
# 10     95
# 36     94
# 26     92
# 38     91
# 25     89
# 37     88
# 31     87
# 0      84
# 24     82
# 11     80
# 13     80
# 5      71
# 16     71
# 6      71
# 29     62
# 1      58
# 2      53
# 20     40
# 19     40
# 27     27
# Name: cluster, dtype: int64

# %%
lrg_cluster1 = a.index[0]

# %%
clusters_large = clusters[clusters['cluster'] == lrg_cluster1]

# %%
clusters_large.index
# Out:
# Int64Index([   1,    7,   38,   49,   51,   57,   73,   74,  104,  105,
#             ...
#             3874, 3910, 3914, 3936, 3940, 3951, 3962, 3966, 3987, 3991],
#            dtype='int64', length=242)

# %%
lrg_cluster1_df = similarity_vector.loc[clusters_large.index, clusters_large.index]
lrg_cluster1_df
# Out:
#           1         7         38        49        51        57        73    \
# 1     1.000000  0.870366  0.916566  0.904868  0.902489  0.908109  0.721893
# 7     0.870366  1.000000  0.928573  0.913719  0.911306  0.919767  0.741280
# 38    0.916566  0.928573  1.000000  0.972043  0.968957  0.946168  0.714398
# 49    0.904868  0.913719  0.972043  1.000000  0.999320  0.944368  0.713619
# 51    0.902489  0.911306  0.968957  0.999320  1.000000  0.941298  0.711655
# ...        ...       ...       ...       ...       ...       ...       ...
# 3951  0.809090  0.841060  0.856329  0.873141  0.869878  0.894053  0.629181
# 3962  0.911161  0.884349  0.896173  0.907658  0.905059  0.881898  0.705146
# 3966  0.912105  0.889566  0.906810  0.927497  0.924777  0.890515  0.826968
# 3987  0.894440  0.936421  0.937525  0.947008  0.944359  0.962710  0.745078
# 3991  0.790215  0.808942  0.899127  0.893119  0.889169  0.897531  0.664463
#
#           74        104       105   ...      3874      3910      3914  \
# 1     0.719578  0.935202  0.928470  ...  0.828749  0.887080  0.873283
# 7     0.695038  0.901887  0.932672  ...  0.845253  0.872418  0.839141
# 38    0.781496  0.926967  0.985753  ...  0.839146  0.910586  0.903054
# 49    0.739995  0.888827  0.972477  ...  0.827069  0.893455  0.928997
# 51    0.737727  0.886254  0.969600  ...  0.824807  0.890412  0.925554
# ...        ...       ...       ...  ...       ...       ...       ...
# 3951  0.659210  0.803840  0.851820  ...  0.825101  0.808075  0.862147
# 3962  0.717686  0.840613  0.912183  ...  0.795748  0.803342  0.932185
# 3966  0.783533  0.862288  0.921954  ...  0.835884  0.888837  0.928571
# 3987  0.718309  0.865874  0.937832  ...  0.782571  0.870580  0.874354
# 3991  0.735195  0.792208  0.867724  ...  0.811629  0.852623  0.929521
#
#           3936      3940      3951      3962      3966      3987      3991
# 1     0.823446  0.861235  0.809090  0.911161  0.912105  0.894440  0.790215
# 7     0.750830  0.828237  0.841060  0.884349  0.889566  0.936421  0.808942
# 38    0.903829  0.889526  0.856329  0.896173  0.906810  0.937525  0.899127
# 49    0.859350  0.876222  0.873141  0.907658  0.927497  0.947008  0.893119
# 51    0.855580  0.872902  0.869878  0.905059  0.924777  0.944359  0.889169
# ...        ...       ...       ...       ...       ...       ...       ...
# 3951  0.821825  0.837293  1.000000  0.805805  0.813676  0.825367  0.909068
# 3962  0.777524  0.825799  0.805805  1.000000  0.939235  0.879992  0.839033
# 3966  0.784368  0.871839  0.813676  0.939235  1.000000  0.902378  0.852553
# 3987  0.798748  0.844976  0.825367  0.879992  0.902378  1.000000  0.826409
# 3991  0.922990  0.892193  0.909068  0.839033  0.852553  0.826409  1.000000
#
# [242 rows x 242 columns]

# %%
lrg_cluster1_df

# %%
kmeans2 = KMeans(n_clusters= 5, random_state=1004).fit(lrg_cluster1_df)
clusters = kmeans2.labels_

clusters2 = pd.DataFrame(clusters)
a2 = clusters2[0].value_counts()

ax2 = a2.plot(kind='bar', title='Number of cluster', figsize=(12, 4), legend=None)
ax2.set_xlabel('Cluster', fontsize=12)
ax2.set_ylabel('Number of documents', fontsize=12)
# Out:
# Text(0, 0.5, 'Number of documents')

# %%
clusters2
# Out:
#      0
# 0    0
# 1    3
# 2    0
# 3    0
# 4    0
# ..  ..
# 237  2
# 238  0
# 239  0
# 240  0
# 241  2
#
# [242 rows x 1 columns]
